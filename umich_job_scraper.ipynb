# %%
import requests
from requests.packages.urllib3.exceptions import InsecureRequestWarning

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

class UMichJob:
    def __init__(self, job_id):
        self.url = f'https://careers.umich.edu/job_detail/{job_id}/'
        self.job_id = job_id
        self.title = ''
        self.location = ''
        self.reg_temp = ''
        self.dept = ''
        self.start_dt = ''
        self.end_dt = ''
        self.salary_low = ''
        self.salary_high = ''
        self.career_interest = ''
    
    def __str__(self):
        return self.url
    
    def __repr__(self):
        return self.__str__()
    
    def __eq__(self, other):
        return self.url == other.url
    
    def __hash__(self):
        return hash(self.url)


def reached_end(soup):
    end_text = 'There are currently no posted jobs fitting the criteria you selected'
    p_tags = soup.find_all('p')
    for p in p_tags:
        if p != None and end_text in p.text:
            return True
    return False

def get_jobs(career_interest = 'All', page_limit = 50, job_limit = None, title = '', keyword = ''):
    jobs = []
    
    for pageNum in range(0,page_limit):
        print(f'Scanning page {pageNum+1}...')
        
        url = f'https://careers.umich.edu/search-jobs?career_interest={career_interest}&page={pageNum}&title={title}&keyword={keyword}'
        response = requests.get(url, verify=False) # TODO: remove verify=False once their site starts working again
        soup = BeautifulSoup(response.text, 'html.parser')

        if reached_end(soup):
            print(f'\nReached the end on page number {pageNum+1}')
            break

        a_tags = soup.find_all('a')
        for a in a_tags:
            href = a.get('href')
            if href != None and 'job_detail' in href:
                job_id = href.split('/')[2]
                jobs.append(UMichJob(job_id))
        
        if job_limit != None and len(jobs) >= job_limit:
            break

    return jobs

def get_job_info(job):
        response = requests.get(job.url, verify=False)
        soup = BeautifulSoup(response.text, 'html.parser')
        
        div_tags = soup.find_all('div')
        
        for div in div_tags:
            h3 = div.find('h3')
            if h3 == None:
                continue
                
            p = div.find('p')
            if p == None:
                continue
                
            h3_text = h3.text.lower()
            p_text = p.text
                    
            if 'working title' in h3_text:
                job.title = p_text
            elif 'work location' in h3_text:
                job.location = p_text
            elif 'regular/temporary' in h3_text:
                job.reg_temp = p_text
            elif 'department' in h3_text:
                job.dept = p_text
            elif 'date' in h3_text:
                date_range = p_text.split(' - ')
                try:
                    job.start_dt = date_range[0]
                    job.end_dt = date_range[1]
                except:
                    print('\tError scraping dates')
            elif 'salary' in h3_text:
                salary_range = p_text.split(' - ')
                try:
                    job.salary_low = salary_range[0]
                    job.salary_high = salary_range[1]
                except:
                    print('\tError scraping salary')
            elif 'interest' in h3_text:
                interests = div.find_all('p')
                for i in interests:
                    job.career_interest += ';' + i.text
                job.career_interest = job.career_interest[1:]

# %%
# IT = 210
jobs = get_jobs(career_interest=210)
jobs.extend(get_jobs(title='analyst'))
jobs.extend(get_jobs(title='data'))
jobs.extend(get_jobs(keyword='python'))
jobs = list(set(jobs))

print(f'{len(jobs)} jobs found')
print('Scraping job info...')
count = 0
for job in jobs:
    count += 1
    print(f'{count}: {job}')
    get_job_info(job)

job_dicts = []

for job in jobs:
    job_dicts.append(vars(job))
    
df = pd.DataFrame(job_dicts)
df
# Out:
# Scanning page 1...
# Scanning page 2...
# Scanning page 3...
#
# Reached the end on page number 3
# Scanning page 1...
# Scanning page 2...
#
# Reached the end on page number 2
# Scanning page 1...
# Scanning page 2...
#
# Reached the end on page number 2
# Scanning page 1...
# Scanning page 2...
# Scanning page 3...
#
# Reached the end on page number 3
# 65 jobs found
# Scraping job info...
# 1: https://careers.umich.edu/job_detail/239645/
# 2: https://careers.umich.edu/job_detail/238453/
# 3: https://careers.umich.edu/job_detail/231143/
# 4: https://careers.umich.edu/job_detail/239849/
# 5: https://careers.umich.edu/job_detail/239765/
# 6: https://careers.umich.edu/job_detail/229396/
# 7: https://careers.umich.edu/job_detail/238762/
# 8: https://careers.umich.edu/job_detail/233405/
# 9: https://careers.umich.edu/job_detail/239192/
# 10: https://careers.umich.edu/job_detail/239652/
# 11: https://careers.umich.edu/job_detail/239492/
# 12: https://careers.umich.edu/job_detail/229901/
# 	Error scraping dates
# 13: https://careers.umich.edu/job_detail/239750/
# 14: https://careers.umich.edu/job_detail/239530/
# 15: https://careers.umich.edu/job_detail/239495/
# 16: https://careers.umich.edu/job_detail/239671/
# 17: https://careers.umich.edu/job_detail/229150/
# 18: https://careers.umich.edu/job_detail/236884/
# 19: https://careers.umich.edu/job_detail/237502/
# 20: https://careers.umich.edu/job_detail/239972/
# 21: https://careers.umich.edu/job_detail/236218/
# 22: https://careers.umich.edu/job_detail/239865/
# 23: https://careers.umich.edu/job_detail/239796/
# 24: https://careers.umich.edu/job_detail/239745/
# 25: https://careers.umich.edu/job_detail/239647/
# 26: https://careers.umich.edu/job_detail/239771/
# 27: https://careers.umich.edu/job_detail/239344/
# 28: https://careers.umich.edu/job_detail/239907/
# 29: https://careers.umich.edu/job_detail/206110/
# 30: https://careers.umich.edu/job_detail/239820/
# 31: https://careers.umich.edu/job_detail/239185/
# 32: https://careers.umich.edu/job_detail/239213/
# 33: https://careers.umich.edu/job_detail/239065/
# 34: https://careers.umich.edu/job_detail/239533/
# 35: https://careers.umich.edu/job_detail/237475/
# 36: https://careers.umich.edu/job_detail/239518/
# 37: https://careers.umich.edu/job_detail/229148/
# 38: https://careers.umich.edu/job_detail/236062/
# 39: https://careers.umich.edu/job_detail/239201/
# 40: https://careers.umich.edu/job_detail/239412/
# 41: https://careers.umich.edu/job_detail/239947/
# 	Error scraping salary
# 42: https://careers.umich.edu/job_detail/238510/
# 43: https://careers.umich.edu/job_detail/233520/
# 44: https://careers.umich.edu/job_detail/239806/
# 45: https://careers.umich.edu/job_detail/239173/
# 46: https://careers.umich.edu/job_detail/239559/
# 47: https://careers.umich.edu/job_detail/235521/
# 	Error scraping salary
# 48: https://careers.umich.edu/job_detail/239479/
# 49: https://careers.umich.edu/job_detail/235800/
# 50: https://careers.umich.edu/job_detail/240010/
# 51: https://careers.umich.edu/job_detail/239538/
# 52: https://careers.umich.edu/job_detail/238883/
# 53: https://careers.umich.edu/job_detail/239966/
# 54: https://careers.umich.edu/job_detail/239885/
# 55: https://careers.umich.edu/job_detail/239659/
# 56: https://careers.umich.edu/job_detail/239742/
# 57: https://careers.umich.edu/job_detail/239756/
# 58: https://careers.umich.edu/job_detail/239591/
# 59: https://careers.umich.edu/job_detail/239949/
# 60: https://careers.umich.edu/job_detail/237067/
# 61: https://careers.umich.edu/job_detail/239791/
# 62: https://careers.umich.edu/job_detail/239751/
# 63: https://careers.umich.edu/job_detail/239686/
# 64: https://careers.umich.edu/job_detail/239799/
# 65: https://careers.umich.edu/job_detail/239794/
#                                              url  job_id  \
# 0   https://careers.umich.edu/job_detail/239645/  239645
# 1   https://careers.umich.edu/job_detail/238453/  238453
# 2   https://careers.umich.edu/job_detail/231143/  231143
# 3   https://careers.umich.edu/job_detail/239849/  239849
# 4   https://careers.umich.edu/job_detail/239765/  239765
# ..                                           ...     ...
# 60  https://careers.umich.edu/job_detail/239791/  239791
# 61  https://careers.umich.edu/job_detail/239751/  239751
# 62  https://careers.umich.edu/job_detail/239686/  239686
# 63  https://careers.umich.edu/job_detail/239799/  239799
# 64  https://careers.umich.edu/job_detail/239794/  239794
#
#                                                 title  \
# 0                        Claims Data Analyst Sr/Inter
# 1                                     RESEARCH FELLOW
# 2                     Research App Programmer/Analyst
# 3   Business Intelligence Analyst Senior / Interme...
# 4               RESEARCH ASST I (TEMP) - Data Science
# ..                                                ...
# 60                   Clinical Info Analyst Sr / Inter
# 61     Business Systems Analyst Senior / Intermediate
# 62              Business Systems Analyst Intermediate
# 63                   Training Specialist Intermediate
# 64                          IT Instructional Designer
#
#                          location   reg_temp                            dept  \
# 0                Ann Arbor Campus    Regular              MM Family Medicine
# 1                Ann Arbor Campus    Regular  MM Int Med-Hematology/Oncology
# 2                Ann Arbor Campus    Regular        Biostatistics Department
# 3   Michigan Medicine - Ann Arbor    Regular  MM HITS EDIS Dpt Info Delivery
# 4                    Flint Campus  Temporary                     Flint IDEAS
# ..                            ...        ...                             ...
# 60  Michigan Medicine - Ann Arbor    Regular  MM Quality - Quality Reporting
# 61  Michigan Medicine - Ann Arbor    Regular  HITS AcadIT Application Servic
# 62  Michigan Medicine - Ann Arbor    Regular  HITS AcadIT Application Servic
# 63  Michigan Medicine - Ann Arbor    Regular     MM HITS BusIT LDD Wolverine
# 64  Michigan Medicine - Ann Arbor    Regular     MM HITS BusIT LDD Wolverine
#
#      start_dt      end_dt  salary_low  salary_high  \
# 0   9/19/2023   9/26/2023
# 1   8/31/2023   9/30/2023
# 2   9/11/2023   9/30/2023  $87,324.00  $107,871.00
# 3   9/22/2023  10/06/2023
# 4   9/21/2023   1/13/2024      $15.00       $15.00
# ..        ...         ...         ...          ...
# 60  9/20/2023  10/04/2023  $58,540.00  $102,610.00
# 61  9/21/2023  10/05/2023
# 62  9/18/2023  10/02/2023
# 63  9/21/2023  10/05/2023
# 64  9/21/2023  10/05/2023
#
#                            career_interest
# 0                                 Research
# 1                         Research Fellows
# 2                   Information Technology
# 3    Administration;Information Technology
# 4                    Temporary Job Opening
# ..                                     ...
# 60              Healthcare Admin & Support
# 61                  Information Technology
# 62                  Information Technology
# 63  Human Resources;Information Technology
# 64  Human Resources;Information Technology
#
# [65 rows x 11 columns]

# %%
df.to_csv('umich_jobs.csv', index=False)
