# %%
import requests
from requests.packages.urllib3.exceptions import InsecureRequestWarning

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

class UMichJob:
    def __init__(self, job_id):
        self.url = f'https://careers.umich.edu/job_detail/{job_id}/'
        self.job_id = job_id
        self.title = ''
        self.location = ''
        self.reg_temp = ''
        self.dept = ''
        self.start_dt = ''
        self.end_dt = ''
        self.salary_low = ''
        self.salary_high = ''
        self.career_interest = ''
    
    def __str__(self):
        return self.url
    
    def __repr__(self):
        return self.__str__()


def reached_end(soup):
    end_text = 'There are currently no posted jobs fitting the criteria you selected'
    p_tags = soup.find_all('p')
    for p in p_tags:
        if p != None and end_text in p.text:
            return True
    return False

def get_jobs(career_interest = 'All', page_limit = 50, job_limit = None):
    jobs = []
    
    for pageNum in range(0,page_limit):
        print(f'Scanning page {pageNum+1}...')
        
        url = f'https://careers.umich.edu/search-jobs?career_interest={career_interest}&page={pageNum}'
        response = requests.get(url, verify=False) # TODO: remove this once their site starts working again
        soup = BeautifulSoup(response.text, 'html.parser')

        if reached_end(soup):
            print(f'\nReached the end on page number {pageNum+1}')
            break

        a_tags = soup.find_all('a')
        for a in a_tags:
            href = a.get('href')
            if href != None and 'job_detail' in href:
                job_id = href.split('/')[2]
                jobs.append(UMichJob(job_id))
        
        if job_limit != None and len(jobs) >= job_limit:
            break

    return jobs

def get_job_info(job):
        response = requests.get(job.url, verify=False)
        soup = BeautifulSoup(response.text, 'html.parser')
        
        div_tags = soup.find_all('div')
        
        for div in div_tags:
            h3 = div.find('h3')
            if h3 == None:
                continue
                
            p = div.find('p')
            if p == None:
                continue
                
            h3_text = h3.text.lower()
            p_text = p.text
                    
            if 'working title' in h3_text:
                job.title = p_text
            elif 'work location' in h3_text:
                job.location = p_text
            elif 'regular/temporary' in h3_text:
                job.reg_temp = p_text
            elif 'department' in h3_text:
                job.dept = p_text
            elif 'date' in h3_text:
                date_range = p_text.split(' - ')
                try:
                    job.start_dt = date_range[0]
                    job.end_dt = date_range[1]
                except:
                    print('\tError scraping dates')
            elif 'salary' in h3_text:
                salary_range = p_text.split(' - ')
                try:
                    job.salary_low = salary_range[0]
                    job.salary_high = salary_range[1]
                except:
                    print('\tError scraping salary')
            elif 'interest' in h3_text:
                interests = div.find_all('p')
                for i in interests:
                    job.career_interest += ';' + i.text
                job.career_interest = job.career_interest[1:]

# %%
# IT = 210
jobs = get_jobs(career_interest=210)

print(f'{len(jobs)} jobs found')
print('Scraping job info...')
count = 0
for job in jobs:
    count += 1
    print(f'{count}: {job}')
    get_job_info(job)

job_dicts = []

for job in jobs:
    job_dicts.append(vars(job))
    
df = pd.DataFrame(job_dicts)
df
# Out:
# Scanning page 1...
# Scanning page 2...
#
# Reached the end on page number 2
# 21 jobs found
# Scraping job info...
# 1: https://careers.umich.edu/job_detail/237148/
# 2: https://careers.umich.edu/job_detail/237266/
# 3: https://careers.umich.edu/job_detail/237215/
# 4: https://careers.umich.edu/job_detail/237182/
# 5: https://careers.umich.edu/job_detail/237155/
# 6: https://careers.umich.edu/job_detail/236058/
# 7: https://careers.umich.edu/job_detail/237143/
# 8: https://careers.umich.edu/job_detail/237152/
# 9: https://careers.umich.edu/job_detail/237078/
# 10: https://careers.umich.edu/job_detail/237121/
# 11: https://careers.umich.edu/job_detail/237003/
# 12: https://careers.umich.edu/job_detail/236894/
# 13: https://careers.umich.edu/job_detail/236903/
# 14: https://careers.umich.edu/job_detail/236815/
# 15: https://careers.umich.edu/job_detail/236840/
# 16: https://careers.umich.edu/job_detail/236747/
# 17: https://careers.umich.edu/job_detail/236758/
# 18: https://careers.umich.edu/job_detail/233405/
# 19: https://careers.umich.edu/job_detail/236436/
# 20: https://careers.umich.edu/job_detail/231143/
# 21: https://careers.umich.edu/job_detail/229396/
#                                              url  job_id  \
# 0   https://careers.umich.edu/job_detail/237148/  237148
# 1   https://careers.umich.edu/job_detail/237266/  237266
# 2   https://careers.umich.edu/job_detail/237215/  237215
# 3   https://careers.umich.edu/job_detail/237182/  237182
# 4   https://careers.umich.edu/job_detail/237155/  237155
# 5   https://careers.umich.edu/job_detail/236058/  236058
# 6   https://careers.umich.edu/job_detail/237143/  237143
# 7   https://careers.umich.edu/job_detail/237152/  237152
# 8   https://careers.umich.edu/job_detail/237078/  237078
# 9   https://careers.umich.edu/job_detail/237121/  237121
# 10  https://careers.umich.edu/job_detail/237003/  237003
# 11  https://careers.umich.edu/job_detail/236894/  236894
# 12  https://careers.umich.edu/job_detail/236903/  236903
# 13  https://careers.umich.edu/job_detail/236815/  236815
# 14  https://careers.umich.edu/job_detail/236840/  236840
# 15  https://careers.umich.edu/job_detail/236747/  236747
# 16  https://careers.umich.edu/job_detail/236758/  236758
# 17  https://careers.umich.edu/job_detail/233405/  233405
# 18  https://careers.umich.edu/job_detail/236436/  236436
# 19  https://careers.umich.edu/job_detail/231143/  231143
# 20  https://careers.umich.edu/job_detail/229396/  229396
#
#                                           title  \
# 0                  ERP Business Systems Analyst
# 1                Programmer Senior/Intermediate
# 2      Senior Full Stack and Systems Programmer
# 3           Service Center Technician Associate
# 4            Application Developer Intermediate
# 5           Data Integration Specialist for BIM
# 6            Business Systems Analyst Associate
# 7              Research Cloud Solution Designer
# 8                Database Analyst/Programmer Sr
# 9                 Drupal Developer Intermediate
# 10                         Intermediate Analyst
# 11              MiSOC Technical Program Manager
# 12           Systems Administrator Intermediate
# 13                    Epic Technical Specialist
# 14  Merit Support Center (MSC) Network Engineer
# 15             Software Programmer Intermediate
# 16                              DevOps Engineer
# 17          App Programmer/Analyst Intermediate
# 18      Storage Research Data Specialist Senior
# 19              Research App Programmer/Analyst
# 20                        Data Security Analyst
#
#                          location reg_temp                            dept  \
# 0                Ann Arbor Campus  Regular                ITS EAS HR Admin
# 1                Ann Arbor Campus  Regular        Biostatistics Department
# 2                Ann Arbor Campus  Regular         MM Pathology Department
# 3                Ann Arbor Campus  Regular                DENT Informatics
# 4                Ann Arbor Campus  Regular   ITS T&L Teaching and Learning
# 5                Ann Arbor Campus  Regular    Facilities & Operations - IS
# 6                Ann Arbor Campus  Regular         ITS SS Support Services
# 7                Ann Arbor Campus  Regular  ITS ARC Advanced Research Comp
# 8                Ann Arbor Campus  Regular    MM Ophthal. & Visual Science
# 9                 Dearborn Campus  Regular          Dbn External Relations
# 10               Ann Arbor Campus  Regular  Kidney Epidemiology & Cost Ctr
# 11               Ann Arbor Campus  Regular                   Merit Network
# 12               Ann Arbor Campus  Regular  LSA Dean: TS Res,Comp&InfrSvcs
# 13  Michigan Medicine - Ann Arbor  Regular   MM HITS ETS InfraSvcs-MiChart
# 14               Ann Arbor Campus  Regular                   Merit Network
# 15               Ann Arbor Campus  Regular  LSA Dean: TS Res,Comp&InfrSvcs
# 16               Ann Arbor Campus  Regular                           ICPSR
# 17               Ann Arbor Campus  Regular           MM MICHR - Operations
# 18               Ann Arbor Campus  Regular  ITS ARC Advanced Research Comp
# 19               Ann Arbor Campus  Regular        Biostatistics Department
# 20               Ann Arbor Campus  Regular        Biostatistics Department
#
#      start_dt     end_dt   salary_low  salary_high         career_interest
# 0   7/24/2023  8/07/2023   $88,000.00  $100,000.00  Information Technology
# 1   7/21/2023  8/18/2023   $87,242.00  $107,770.00  Information Technology
# 2   7/20/2023  7/27/2023                            Information Technology
# 3   7/20/2023  8/03/2023   $43,000.00   $50,000.00  Information Technology
# 4   7/20/2023  8/03/2023   $70,916.00   $78,795.00  Information Technology
# 5   7/20/2023  8/03/2023   $90,000.00  $105,000.00  Information Technology
# 6   7/19/2023  8/02/2023   $55,800.00   $62,000.00  Information Technology
# 7   7/19/2023  8/16/2023   $70,000.00   $80,000.00  Information Technology
# 8   7/19/2023  8/18/2023                            Information Technology
# 9   7/18/2023  8/01/2023   $80,000.00   $90,000.00  Information Technology
# 10  7/14/2023  8/18/2023   $68,033.00   $84,040.00  Information Technology
# 11  7/13/2023  7/27/2023  $110,000.00  $120,000.00  Information Technology
# 12  7/13/2023  7/31/2023   $69,000.00   $75,000.00  Information Technology
# 13  7/13/2023  7/30/2023                            Information Technology
# 14  7/12/2023  8/02/2023   $65,000.00   $75,000.00  Information Technology
# 15  7/10/2023  8/07/2023   $70,000.00   $77,000.00  Information Technology
# 16  7/10/2023  8/06/2023   $75,000.00   $95,000.00  Information Technology
# 17  7/07/2023  8/06/2023                            Information Technology
# 18  7/03/2023  7/31/2023   $99,000.00  $121,000.00  Information Technology
# 19  7/03/2023  7/31/2023   $87,324.00  $107,871.00  Information Technology
# 20  7/03/2023  7/31/2023   $89,599.00  $110,681.00  Information Technology

# %%
df.to_csv('umich_jobs.csv', index=False)
