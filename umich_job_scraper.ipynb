# %%
import requests
from requests.packages.urllib3.exceptions import InsecureRequestWarning

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

class UMichJob:
    def __init__(self, job_id):
        self.url = f'https://careers.umich.edu/job_detail/{job_id}/'
        self.job_id = job_id
        self.title = ''
        self.location = ''
        self.reg_temp = ''
        self.dept = ''
        self.start_dt = ''
        self.end_dt = ''
        self.salary_low = ''
        self.salary_high = ''
        self.career_interest = ''
    
    def __str__(self):
        return self.url
    
    def __repr__(self):
        return self.__str__()
    
    def __eq__(self, other):
        return self.url == other.url
    
    def __hash__(self):
        return hash(self.url)


def reached_end(soup):
    end_text = 'There are currently no posted jobs fitting the criteria you selected'
    p_tags = soup.find_all('p')
    for p in p_tags:
        if p != None and end_text in p.text:
            return True
    return False

def get_jobs(career_interest = 'All', page_limit = 50, job_limit = None, title = '', keyword = ''):
    jobs = []
    
    for pageNum in range(0,page_limit):
        print(f'Scanning page {pageNum+1}...')
        
        url = f'https://careers.umich.edu/search-jobs?career_interest={career_interest}&page={pageNum}&title={title}&keyword={keyword}'
        response = requests.get(url, verify=False) # TODO: remove verify=False once their site starts working again
        soup = BeautifulSoup(response.text, 'html.parser')

        if reached_end(soup):
            print(f'\nReached the end on page number {pageNum+1}')
            break

        a_tags = soup.find_all('a')
        for a in a_tags:
            href = a.get('href')
            if href != None and 'job_detail' in href:
                job_id = href.split('/')[2]
                jobs.append(UMichJob(job_id))
        
        if job_limit != None and len(jobs) >= job_limit:
            break

    return jobs

def get_job_info(job):
        response = requests.get(job.url, verify=False)
        soup = BeautifulSoup(response.text, 'html.parser')
        
        div_tags = soup.find_all('div')
        
        for div in div_tags:
            h3 = div.find('h3')
            if h3 == None:
                continue
                
            p = div.find('p')
            if p == None:
                continue
                
            h3_text = h3.text.lower()
            p_text = p.text
                    
            if 'working title' in h3_text:
                job.title = p_text
            elif 'work location' in h3_text:
                job.location = p_text
            elif 'regular/temporary' in h3_text:
                job.reg_temp = p_text
            elif 'department' in h3_text:
                job.dept = p_text
            elif 'date' in h3_text:
                date_range = p_text.split(' - ')
                try:
                    job.start_dt = date_range[0]
                    job.end_dt = date_range[1]
                except:
                    print('\tError scraping dates')
            elif 'salary' in h3_text:
                salary_range = p_text.split(' - ')
                try:
                    job.salary_low = salary_range[0]
                    job.salary_high = salary_range[1]
                except:
                    print('\tError scraping salary')
            elif 'interest' in h3_text:
                interests = div.find_all('p')
                for i in interests:
                    job.career_interest += ';' + i.text
                job.career_interest = job.career_interest[1:]

# %%
# IT = 210
jobs = get_jobs(career_interest=210)
jobs.extend(get_jobs(title='analyst'))
jobs.extend(get_jobs(title='data'))
jobs.extend(get_jobs(keyword='python'))
jobs = list(set(jobs))

print(f'{len(jobs)} jobs found')
print('Scraping job info...')
count = 0
for job in jobs:
    count += 1
    print(f'{count}: {job}')
    get_job_info(job)

job_dicts = []

for job in jobs:
    job_dicts.append(vars(job))
    
df = pd.DataFrame(job_dicts)
df
# Out:
# Scanning page 1...
# Scanning page 2...
# Scanning page 3...
#
# Reached the end on page number 3
# Scanning page 1...
# Scanning page 2...
#
# Reached the end on page number 2
# Scanning page 1...
# Scanning page 2...
#
# Reached the end on page number 2
# Scanning page 1...
# Scanning page 2...
# Scanning page 3...
#
# Reached the end on page number 3
# 62 jobs found
# Scraping job info...
# 1: https://careers.umich.edu/job_detail/239806/
# 2: https://careers.umich.edu/job_detail/238453/
# 3: https://careers.umich.edu/job_detail/206110/
# 4: https://careers.umich.edu/job_detail/239344/
# 5: https://careers.umich.edu/job_detail/239865/
# 6: https://careers.umich.edu/job_detail/239885/
# 7: https://careers.umich.edu/job_detail/239591/
# 8: https://careers.umich.edu/job_detail/239742/
# 9: https://careers.umich.edu/job_detail/239530/
# 10: https://careers.umich.edu/job_detail/229150/
# 11: https://careers.umich.edu/job_detail/239750/
# 12: https://careers.umich.edu/job_detail/239065/
# 13: https://careers.umich.edu/job_detail/239559/
# 14: https://careers.umich.edu/job_detail/239533/
# 15: https://careers.umich.edu/job_detail/229901/
# 	Error scraping dates
# 16: https://careers.umich.edu/job_detail/237502/
# 17: https://careers.umich.edu/job_detail/239765/
# 18: https://careers.umich.edu/job_detail/229396/
# 19: https://careers.umich.edu/job_detail/233520/
# 20: https://careers.umich.edu/job_detail/239213/
# 21: https://careers.umich.edu/job_detail/233405/
# 22: https://careers.umich.edu/job_detail/239412/
# 23: https://careers.umich.edu/job_detail/239947/
# 	Error scraping salary
# 24: https://careers.umich.edu/job_detail/231143/
# 25: https://careers.umich.edu/job_detail/239849/
# 26: https://careers.umich.edu/job_detail/238762/
# 27: https://careers.umich.edu/job_detail/239686/
# 28: https://careers.umich.edu/job_detail/239185/
# 29: https://careers.umich.edu/job_detail/239791/
# 30: https://careers.umich.edu/job_detail/238883/
# 31: https://careers.umich.edu/job_detail/239538/
# 32: https://careers.umich.edu/job_detail/239492/
# 33: https://careers.umich.edu/job_detail/239173/
# 34: https://careers.umich.edu/job_detail/239949/
# 35: https://careers.umich.edu/job_detail/239799/
# 36: https://careers.umich.edu/job_detail/239518/
# 37: https://careers.umich.edu/job_detail/236884/
# 38: https://careers.umich.edu/job_detail/237475/
# 39: https://careers.umich.edu/job_detail/239479/
# 40: https://careers.umich.edu/job_detail/239966/
# 41: https://careers.umich.edu/job_detail/239794/
# 42: https://careers.umich.edu/job_detail/235521/
# 	Error scraping salary
# 43: https://careers.umich.edu/job_detail/236218/
# 44: https://careers.umich.edu/job_detail/239671/
# 45: https://careers.umich.edu/job_detail/239201/
# 46: https://careers.umich.edu/job_detail/239647/
# 47: https://careers.umich.edu/job_detail/237067/
# 48: https://careers.umich.edu/job_detail/239751/
# 49: https://careers.umich.edu/job_detail/239756/
# 50: https://careers.umich.edu/job_detail/239495/
# 51: https://careers.umich.edu/job_detail/239645/
# 52: https://careers.umich.edu/job_detail/229148/
# 53: https://careers.umich.edu/job_detail/239820/
# 54: https://careers.umich.edu/job_detail/238510/
# 55: https://careers.umich.edu/job_detail/239745/
# 56: https://careers.umich.edu/job_detail/235800/
# 57: https://careers.umich.edu/job_detail/239771/
# 58: https://careers.umich.edu/job_detail/239659/
# 59: https://careers.umich.edu/job_detail/239192/
# 60: https://careers.umich.edu/job_detail/239796/
# 61: https://careers.umich.edu/job_detail/239652/
# 62: https://careers.umich.edu/job_detail/236062/
#                                              url  job_id  \
# 0   https://careers.umich.edu/job_detail/239806/  239806
# 1   https://careers.umich.edu/job_detail/238453/  238453
# 2   https://careers.umich.edu/job_detail/206110/  206110
# 3   https://careers.umich.edu/job_detail/239344/  239344
# 4   https://careers.umich.edu/job_detail/239865/  239865
# ..                                           ...     ...
# 57  https://careers.umich.edu/job_detail/239659/  239659
# 58  https://careers.umich.edu/job_detail/239192/  239192
# 59  https://careers.umich.edu/job_detail/239796/  239796
# 60  https://careers.umich.edu/job_detail/239652/  239652
# 61  https://careers.umich.edu/job_detail/236062/  236062
#
#                                                 title  \
# 0                          OS Programmer Intermediate
# 1                                     RESEARCH FELLOW
# 2                         Research Computer Scientist
# 3                   Director of Data Science Practice
# 4                         Clinical Info Analyst Inter
# ..                                                ...
# 57              Business Systems Analyst Intermediate
# 58                                       Data Manager
# 59                     Business Systems Analyst Inter
# 60  MiChart Research Application Coordinator (Sr /...
# 61  Bioinformatician-Computational Biologist Assoc...
#
#                          location reg_temp                            dept  \
# 0   Michigan Medicine - Ann Arbor  Regular  MM HITS AcadIT Tech Svc/Engage
# 1                Ann Arbor Campus  Regular  MM Int Med-Hematology/Oncology
# 2                Ann Arbor Campus  Regular                      MM Urology
# 3                Ann Arbor Campus  Regular   ITS DSP Data Science Practice
# 4   Michigan Medicine - Ann Arbor  Regular    MM Nsg OH Prg Nsg Excellence
# ..                            ...      ...                             ...
# 57  Michigan Medicine - Ann Arbor  Regular  HITS AcadIT Application Servic
# 58               Ann Arbor Campus  Regular   MM Mary H Weiser Food Allergy
# 59  Michigan Medicine - Ann Arbor  Regular              MM Rev Cycle (PTO)
# 60  Michigan Medicine - Ann Arbor  Regular  HITS AcadIT Application Servic
# 61               Ann Arbor Campus  Regular  MM Microbiology and Immunology
#
#      start_dt      end_dt  salary_low salary_high             career_interest
# 0   9/21/2023  10/05/2023                              Information Technology
# 1   8/31/2023   9/30/2023                                    Research Fellows
# 2   6/01/2023   9/30/2023                                            Research
# 3   9/11/2023  10/26/2023                              Information Technology
# 4   9/21/2023   9/28/2023                          Healthcare Admin & Support
# ..        ...         ...         ...         ...                         ...
# 57  9/18/2023  10/02/2023                              Information Technology
# 58  9/07/2023  10/07/2023  $58,480.00  $93,560.00                    Research
# 59  9/21/2023  10/19/2023                              Information Technology
# 60  9/19/2023  10/03/2023                              Information Technology
# 61  8/12/2023  10/11/2023                                            Research
#
# [62 rows x 11 columns]

# %%
df.to_csv('umich_jobs.csv', index=False)
